# %% [markdown]
# # Survival Analysis (Kaplan–Meier) in Colab
# This notebook uses **Python kernel** with **rpy2** to run R code inside Colab.

# %%
# !pip install rpy2==3.5.11

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# summary(cars)

# %%
# %%R
# install.packages("survival", repos="https://cloud.r-project.org")
# library(survival)
#
# data(lung)
# fit <- survfit(Surv(time, status) ~ sex, data=lung)
# plot(fit, col=1:2, main="Kaplan–Meier Curve")
